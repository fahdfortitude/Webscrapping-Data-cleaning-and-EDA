# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook shows how data on properties in lagos were collected, in essence the datasets will be divided into sales and rents.
#
# Specifically, the following steps will be taken:
#
# 1. **Exploring the website** - inspecting the website.
# 2. **Extracting the data** - we will download the datasets and turn them into pandas dataframe
# 3. **Organizing the data into csv files**

# %% [markdown]
# #### Exploring the website

# %%
import requests
from bs4 import BeautifulSoup as soup
import numpy as np
import pandas as pd

# %%
rent_link ="https://www.privateproperty.com.ng/flats-apartments-for-rent/lagos/serviced"
sales_link="https://www.privateproperty.com.ng/flats-apartments-for-sale/lagos/serviced"

# %% [markdown]
# To explore the pages, we will explore the first page from rent_link

# %%
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}
# we use header to disguise as a web-browser
with requests.get(rent_link, headers=header) as property_html: #Html Client and html itself
    property_page = soup(property_html.content, "html.parser") # extracts the html code

# %% [markdown]
# Using the inspect, one will find out that the details of each properties is contained in the div tag and class attribute
# on

# %%
# container for details
containers = property_page.findAll("div", {"class": "item-body table-cell"})

# %%
print(containers[0].prettify())
# Out:
# <div class="item-body table-cell">
#  <div class="amenities-grid align-items-start">
#   <div class="body-left table-cell">
#    <div class="info-row calc d-lg-none d-md-none">
#    </div>
#    <div class="info-row price">
#     <a class="item-price" href="/listings/1-bed-mini-serviced-flat-apartment-for-rent-ikeja-gra-off-mobolaji-bank-anthony-ikeja-lagos-ikeja-g-r-a-tosp97236">
#      N1,300,000 per year
#     </a>
#    </div>
#   </div>
#   <div class="body-right table-cell">
#    <div class="info-row amenities">
#     <p>
#      <span class="h-beds">
#       <i class="fa fa-bed">
#       </i>
#       1
#      </span>
#      <span class="h-baths">
#       <i class="fa fa-bathtub">
#       </i>
#       1
#      </span>
#     </p>
#    </div>
#   </div>
#   <ul class="actions favourite-action">
#    <li>
#     <span class="favourite-none listing-favourite btn-favourite" data-t-listing_category="Flat &amp; Apartment" data-t-listing_id="97236" data-t-listing_priority="gold" data-t-listing_type="For Rent" onclick="NewFrontEnd.ProcessFavourite(97236)">
#      <i class="fa fa-heart listing-favourite" data-t-listing_category="Flat &amp; Apartment" data-t-listing_id="97236" data-t-listing_priority="gold" data-t-listing_type="For Rent">
#      </i>
#     </span>
#    </li>
#   </ul>
#   <div class="clearfix">
#   </div>
#  </div>
#  <div class="property-description-grid w-80">
#   <div class="body-desc-left table-cell">
#    <div class="info mb-2">
#     <h2 class="property-title">
#      <a href="/listings/1-bed-mini-serviced-flat-apartment-for-rent-ikeja-gra-off-mobolaji-bank-anthony-ikeja-lagos-ikeja-g-r-a-tosp97236">
#       Serviced 1 Bedroom Flat (Miniflat) with Swimming Pool
#      </a>
#     </h2>
#     <div class="property-location overflow-ellipse-mobile">
#      <span class="fa fa-map-marker text-black">
#      </span>
#      Ikeja Gra, Off Mobolaji Bank Anthony, Ikeja, Lagos., Ikeja G.R.A, Ikeja
#     </div>
#     <div class="property-title-default">
#      Flat &amp; Apartment
#     </div>
#    </div>
#   </div>
#   <div class="clearfix">
#   </div>
#  </div>
#  <div class="property-social-grid d-flex align-items-end">
#   <div class="body-icon-control-left">
#    <div class="info">
#     <span class="estate-agency-logo">
#      <a href="/estate-agents/tospropertyservices">
#       <img alt="Tos Property Services" class="lazy lazyload" data-src="/uploadedfiles/6a/15/7e/6a157e85-bbb3-4ecb-8403-d7184ccb6cec.png"/>
#      </a>
#     </span>
#    </div>
#   </div>
#   <div class="body-icon-control-right">
#    <div class="info float-right">
#     <ul class="actions">
#      <li data-placement="top" data-toggle="tooltip" title="WhatsApp">
#       <span class="listing-send-whatsapp" data-modal-icon="fa fa-whatsapp" data-modal-title="Chat via WhatsApp" data-modal-url="/ContactForm/MandateNumbersWhatsapp/96186?url=https://web.whatsapp.com/send?phone=2348020330657~text=Hi,%20I%20am%20interested%20in%20your%20property%20TOSP97236%20Flat%20%26%20Apartment%20on%20https://www.privateproperty.com.ng/listings/1-bed-mini-serviced-flat-apartment-for-rent-ikeja-gra-off-mobolaji-bank-anthony-ikeja-lagos-ikeja-g-r-a-tosp97236&amp;listingurl=/listings/1-bed-mini-serviced-flat-apartment-for-rent-ikeja-gra-off-mobolaji-bank-anthony-ikeja-lagos-ikeja-g-r-a-tosp97236" data-t-listing_category="Flat &amp; Apartment" data-t-listing_id="97236" data-t-listing_priority="gold" data-t-listing_type="For Rent" data-target="#propertymodal" data-toggle="modal">
#        <i class="fa fa-whatsapp listing-send-whatsapp" data-t-listing_category="Flat &amp; Apartment" data-t-listing_id="97236" data-t-listing_priority="gold" data-t-listing_type="For Rent">
#        </i>
#       </span>
#      </li>
#      <li data-placement="top" data-toggle="tooltip" title="Phone">
#       <span class="listing-open-phone-modal" data-modal-icon="fa fa-phone" data-modal-title="Phone the  Agent /Developer" data-modal-url="/ContactForm/MandateNumbers/96186?listingurl=/listings/1-bed-mini-serviced-flat-apartment-for-rent-ikeja-gra-off-mobolaji-bank-anthony-ikeja-lagos-ikeja-g-r-a-tosp97236" data-t-listing_category="Flat &amp; Apartment" data-t-listing_id="97236" data-t-listing_priority="gold" data-t-listing_type="For Rent" data-target="#propertymodal" data-toggle="modal">
#        <i class="fa fa-phone listing-open-phone-modal" data-t-listing_category="Flat &amp; Apartment" data-t-listing_id="97236" data-t-listing_priority="gold" data-t-listing_type="For Rent">
#        </i>
#       </span>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <div class="clearfix">
#   </div>
#  </div>
# </div>

# %% [markdown]
# A look at the html code above shows the following.

# %%
try:
    # price
    print("price :"+(containers[1].find("div",{"class":'body-left table-cell'}).text.strip()))
except:
    print("price : Unknown")
try:
    # number of bed rooms
    print("Property description :" +containers[1].h2.find('a').text.strip())
except:
    print("Property Description : Unknown")
    
try:
    # number of bed rooms
    print("number of bed rooms :" +containers[1].find('span', {'class':'h-beds'}).text.strip())
except:
    print("number of bed rooms : Unknown")

try:
    # number of bed rooms
    print("number of bathrooms :" +containers[1].find('span', {'class':'h-baths'}).text.strip())
except:
    print("number of bathrooms : Unknown")

try:
    #Location
    print("Location :"+containers[1].find("div", {"class":"property-location"}).text)
except:
    print("Location : Unknown")
# try:
#     #Property adddress 
#     print("Property adddress  :"+containers[0].find("address", {"class":"property-address d-none d-sm-block"}).text.strip())
# except:
#     print("Property adddress  : Unknown")
try:
    #estate agency
    print("estate agency  :"+containers[0].find("span", {"class":"estate-agency-logo"}).a.find("img")["alt"])
except:
    print("estate agency  : Unknown")
# Out:
# price :N25,000,000 per year
# Property description :Exquisite And Well Maintained 3 & 4 Bedroom Apartment With Swimming Pool
# number of bed rooms :3
# number of bathrooms :5
# Location :  Ocean Parade, Banana Island, Banana Island, Ikoyi
# estate agency  :Tos Property Services

# %% [markdown]
# websites are usually standardize and consistent, wrote a for loop to get similar information.

# %%
price=[]
property_description=[]
number_of_bedrooms=[]
number_of_bathrooms=[]
Location=[]
estate_agency=[]


for i in range(len(containers)):
    # price
    try:
        price.append(containers[i].find("div",{"class":'body-left table-cell'}).text.strip())
    except AttributeError:
        price.append(np.nan)
    
    # property description
    try:
        property_description.append(containers[i].h2.find('a').text.strip())
    except AttributeError:
        property_description.append(np.nan)
    
    # number of bedrooms
    try:
       
        number_of_bedrooms.append(containers[i].find('span', {'class':'h-beds'}).text.strip())
    except AttributeError:
        number_of_bedrooms.append(np.nan)
   
    #number of bathrooms
    try:
        number_of_bathrooms.append(containers[i].find('span', {'class':'h-baths'}).text.strip())
    except AttributeError:
        number_of_bathrooms.append(np.nan)


    #Location
    try:
        Location.append(containers[i].find("div", {"class":"property-location"}).text.strip())
    except AttributeError:
        Location.append(np.nan)
    
    
 
    #estate_agency
    try:
        estate_agency.append(containers[i].find("span", {"class":"estate-agency-logo"}).a.find("img")["alt"].strip())
    except AttributeError:
        estate_agency.append(np.nan)
    
    
df=pd.DataFrame({"price":price,"property description":property_description, "number of bedrooms":number_of_bedrooms, 
                    "number of bathrooms": number_of_bathrooms,"Location":Location, "estate agency":estate_agency})
df.head()
# Out:
#                   price                               property description  \
# 0   N1,300,000 per year  Serviced 1 Bedroom Flat (Miniflat) with Swimmi...
# 1  N25,000,000 per year  Exquisite And Well Maintained 3 & 4 Bedroom Ap...
# 2   N7,000,000 per year                    Furnished One Bedroom Apartment
# 3  N15,000,000 per year                           3 bedroom flat with a bq
# 4   N8,000,000 per year  20 units 3 bedroom service and partially furni...
#
#   number of bedrooms number of bathrooms  \
# 0                  1                   1
# 1                  3                   5
# 2                  1                   1
# 3                  3                   3
# 4                  3                   3
#
#                                             Location  \
# 0  Ikeja Gra, Off Mobolaji Bank Anthony, Ikeja, L...
# 1  Ocean Parade, Banana Island, Banana Island, Ikoyi
# 2                               Banana Island, Ikoyi
# 3                               Banana Island, Ikoyi
# 4    Isaac John Street Gra Ikeja, Ikeja G.R.A, Ikeja
#
#                  estate agency
# 0        Tos Property Services
# 1            Ubosi Eleh And Co
# 2             Ifeanyi Igwebike
# 3  Verified properties Limited
# 4             Loyalty Property

# %% [markdown]
# A quick view in as dataframe gives the feeling of what the output will look like, when we combine other pages with the first page

# %% [markdown]
# the second page is "https://www.privateproperty.com.ng/flats-apartments-for-rent/lagos/serviced?page=2",
# it's conspicous that the difference between the first page and subsequent pages is "?page= page_no", as such we can write a function to capture this.

# %%
def get_pivatepropertywebpage (url):
    """
        gets privateproperty.com page
    """
    from bs4 import BeautifulSoup as soup
    import requests
    
    
    header = {
      "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
      "X-Requested-With": "XMLHttpRequest"
    }
   
    # we use header to disguise as a web-browser   
    with requests.get(url, headers=header) as page_htmlclient: #Html Client and html itself
        page_html = soup(page_htmlclient.content, "html.parser") # extracts the html code
    
    # container for details
    property_container = page_html.findAll("div", {"class": "item-body table-cell"})
    return property_container

# %%
def get_properties_info(property_container):
    price=[]
    property_description=[]
    number_of_bedrooms=[]
    number_of_bathrooms=[]
    Location=[]
    estate_agency=[]

    for i in range(len(property_container)):
        # price
        try:
            price.append(property_container[i].find("div",{"class":'body-left table-cell'}).text.strip())
        except AttributeError:
            price.append(np.nan)

        # property description
        try:
            property_description.append(property_container[i].h2.find('a').text.strip())
        except AttributeError:
            property_description.append(np.nan)

        # number of bedrooms
        try:

            number_of_bedrooms.append(property_container[i].find('span', {'class':'h-beds'}).text.strip())
        except AttributeError:
            number_of_bedrooms.append(np.nan)

        #number of bathrooms
        try:
            number_of_bathrooms.append(property_container[i].find('span', {'class':'h-baths'}).text.strip())
        except AttributeError:
            number_of_bathrooms.append(np.nan)


        #Location
        try:
            Location.append(property_container[i].find("div", {"class":"property-location"}).text.strip())
        except AttributeError:
            Location.append(np.nan)



        #estate_agency
        try:
            estate_agency.append(property_container[i].find("span", {"class":"estate-agency-logo"}).a.find("img")["alt"].strip())
        except AttributeError:
            estate_agency.append(np.nan)
    
    #convert info to dictionary
    property_info= {"price":price,"property description":property_description, "number of bedrooms":number_of_bedrooms, 
                     "number of bathrooms": number_of_bathrooms,"Location":Location, "estate agency":estate_agency}
    return property_info

# %%
def get_property_info_from_multiple_pages(page_link, no_of_pages=1):
    assert no_of_pages >= 1
    first_page = get_pivatepropertywebpage(page_link)
    property_dict = get_properties_info(first_page)
    
    if no_of_pages>1:
        import time
        time.sleep(1)
        if no_of_pages==2:
            page = get_pivatepropertywebpage(page_link + '?page=2')
            page_dict = get_properties_info(page)
            for key, value in page_dict.items():
                property_dict[key].extend(value)
        else:
            for i in range(2, no_of_pages+1):
                page = get_pivatepropertywebpage(page_link + f'?page={i}')
                page_dict = get_properties_info(page)
                for key, value in page_dict.items():
                    property_dict[key].extend(value)
                time.sleep(1)
    return property_dict

# %%
rent=get_property_info_from_multiple_pages(rent_link,35)

# %%
sales = get_property_info_from_multiple_pages(sales_link,37)

# %%
rent_df=pd.DataFrame(rent)
sales_df=pd.DataFrame(sales)

# %%
rent_df.head()
# Out:
#                   price                               property description  \
# 0   N1,300,000 per year  Serviced 1 Bedroom Flat (Miniflat) with Swimmi...
# 1  N25,000,000 per year  Exquisite And Well Maintained 3 & 4 Bedroom Ap...
# 2   N7,000,000 per year                    Furnished One Bedroom Apartment
# 3  N15,000,000 per year                           3 bedroom flat with a bq
# 4   N8,000,000 per year  20 units 3 bedroom service and partially furni...
#
#   number of bedrooms number of bathrooms  \
# 0                  1                   1
# 1                  3                   5
# 2                  1                   1
# 3                  3                   3
# 4                  3                   3
#
#                                             Location  \
# 0  Ikeja Gra, Off Mobolaji Bank Anthony, Ikeja, L...
# 1  Ocean Parade, Banana Island, Banana Island, Ikoyi
# 2                               Banana Island, Ikoyi
# 3                               Banana Island, Ikoyi
# 4    Isaac John Street Gra Ikeja, Ikeja G.R.A, Ikeja
#
#                  estate agency
# 0        Tos Property Services
# 1            Ubosi Eleh And Co
# 2             Ifeanyi Igwebike
# 3  Verified properties Limited
# 4             Loyalty Property

# %%
sales_df.head()
# Out:
#          price                               property description  \
# 0  N26,500,000  Newly Built 2 & 3 Bedroom Flat Apartments in S...
# 1  N65,000,000  Luxury 3 Bedroom Flat with Maid's Room, AC, Fi...
# 2  N25,000,000                   Newly Built 2 Bedroom Apartments
# 3  N60,000,000                        3 Bedroom Apartment With Bq
# 4  N48,000,000                              A 3 bedroom apartment
#
#   number of bedrooms number of bathrooms  \
# 0                  4                   4
# 1                  3                   4
# 2                  2                   2
# 3                  3                   4
# 4                  3                   3
#
#                                             Location          estate agency
# 0                   Off Brown Road, Aguda , Surulere        Choice Property
# 1  Along Water Corporation Drive Off Ligali Ayori...  Deluxe Residences Ltd
# 2                  Orchid Road, Chevron Drive, Lekki              JOA Homes
# 3              The Dream Place, Lekki Phase 1, Lekki                    NaN
# 4                       Ikate, Ikate Elegushi, Lekki        Underwood Homes

# %%
sales_df.to_csv('Lagos Properties for sale.csv', index=False)
rent_df.to_csv('Lagos Properties for Rent.xls', index=False)

# %% [markdown]
# The Next notebook will focus on cleaning the generated data sets and some EDAs.

# %% [markdown]
# #### Thank You
